# %% [markdown]
# ##                                                     Cyber Crime Rate Analysis

# %%
# Importing libraries
from faker import Faker
import pandas as pd
import numpy as np
import random

# Initialize Faker to generate fake data
fake = Faker()

# Generate fake data for the DataFrame
data = {
    'Year': [str(year) for year in range(2000, 2024)],
    'Total_Cybercrimes': [random.randint(10000, 50000) for _ in range(24)],
    'Financial_Fraud': [random.randint(2000, 10000) for _ in range(24)],
    'Identity_Theft': [random.randint(1000, 8000) for _ in range(24)],
    'Cyberbullying': [random.randint(500, 3000) for _ in range(24)],
    'Hacking': [random.randint(200, 5000) for _ in range(24)],
    'Data_Breaches': [random.randint(500, 4000) for _ in range(24)],
    'Economic_Cybercrimes': [random.randint(1000, 10000) for _ in range(24)],
    'Online_Scams': [random.randint(500, 2000) for _ in range(24)],
    'Phishing_Attacks': [random.randint(200, 1000) for _ in range(24)],
    'Ransomware_Attacks': [random.randint(100, 500) for _ in range(24)],
    'Malware_Infections': [random.randint(500, 3000) for _ in range(24)],
    'Social_Media_Fraud': [random.randint(200, 1000) for _ in range(24)],
    'Dark_Web_Activity': [random.randint(100, 500) for _ in range(24)],
    'Cybersecurity_Breaches': [random.randint(500, 2000) for _ in range(24)],
    'Cases_Charge_Sheeted': [random.randint(200, 1000) for _ in range(24)],
    'Persons_Arrested': [random.randint(500, 3000) for _ in range(24)]
}

# Create DataFrame
df = pd.DataFrame(data)

# Reorder the columns
df = df[['Year', 'Total_Cybercrimes', 'Financial_Fraud', 'Identity_Theft', 
         'Cyberbullying', 'Hacking', 'Data_Breaches', 'Economic_Cybercrimes', 
         'Online_Scams', 'Phishing_Attacks', 'Ransomware_Attacks', 'Malware_Infections', 
         'Social_Media_Fraud', 'Dark_Web_Activity', 'Cybersecurity_Breaches',
         'Cases_Charge_Sheeted', 'Persons_Arrested']]

# Display the DataFrame
print(df)
# Out:
#     Year  Total_Cybercrimes  Financial_Fraud  Identity_Theft  Cyberbullying  \
# 0   2000              31118             7130            5739           1401
# 1   2001              12594             9082            1447           2468
# 2   2002              46936             4069            1539           1030
# 3   2003              42585             4973            6396           1542
# 4   2004              37195             5919            7102           1497
# 5   2005              14767             6252            6177           1507
# 6   2006              35637             2685            7676           2093
# 7   2007              29142             6073            4886           1885
# 8   2008              26564             7568            1103           2898
# 9   2009              27821             4705            6807           1843
# 10  2010              46077             6736            2602           2422
# 11  2011              16826             8198            5786           2381
# 12  2012              44134             7528            4573           2188
# 13  2013              25374             5638            7934            876
# 14  2014              32672             5342            4937           2602
# 15  2015              49596             2075            4605           1922
# 16  2016              14167             8860            7716            669
# 17  2017              34129             9333            3242            586
# 18  2018              47669             3998            7749           1333
# 19  2019              42941             4253            6841           2794
# 20  2020              22873             7885            3807           1848
# 21  2021              36982             7278            4968           2807
# 22  2022              20845             3796            4875           2356
# 23  2023              23012             4661            4440           2405
#
#     Hacking  Data_Breaches  Economic_Cybercrimes  Online_Scams  \
# 0      1576           1653                  8766          1521
# 1      4415           2705                  3903          1143
# 2      3943           1014                  7052           511
# 3       368           1299                  9785           656
# 4       757           2711                  4079          1190
# 5      3001           1817                  9433          1208
# 6      3475           1419                  7907          1851
# 7      3657           3547                  4744           807
# 8      4383            755                  5655          1866
# 9       365           2295                  7144           747
# 10     4168            839                  6443          1019
# 11     3061            756                  5920          1515
# 12      564           2454                  8884          1412
# 13     1100           2621                  7886          1238
# 14     2660           3252                  8570          1155
# 15     4903           1357                  6781          1748
# 16     4438           2999                  6476          1249
# 17     2429           2563                  7439          1992
# 18     1090           1402                  8293          1585
# 19     3046           3324                  6759           820
# 20     1778           1290                  1920          1093
# 21      325           2718                  1918           805
# 22     4839            645                  6787          1102
# 23     2280           2474                  5201           900
#
#     Phishing_Attacks  Ransomware_Attacks  Malware_Infections  \
# 0                423                 191                1373
# 1                969                 167                2143
# 2                492                 255                1384
# 3                630                 373                2684
# 4                270                 292                2543
# 5                288                 494                 979
# 6                963                 255                1608
# 7                894                 400                2144
# 8                540                 252                2717
# 9                301                 267                1971
# 10               456                 404                2477
# 11               744                 304                2358
# 12               572                 238                1331
# 13               485                 483                 900
# 14               929                 181                1650
# 15               719                 174                1433
# 16               737                 449                 832
# 17               294                 497                1429
# 18               607                 431                1422
# 19               475                 453                 908
# 20               895                 191                2164
# 21               342                 363                1249
# 22               762                 324                 851
# 23               849                 364                2857
#
#     Social_Media_Fraud  Dark_Web_Activity  Cybersecurity_Breaches  \
# 0                  271                325                    1658
# 1                  236                142                     712
# 2                  579                137                    1624
# 3                  739                321                     548
# 4                  730                221                    1344
# 5                  524                207                    1063
# 6                  268                333                     527
# 7                  274                222                    1377
# 8                  747                107                     913
# 9                  521                116                     525
# 10                 851                161                     827
# 11                 745                150                    1393
# 12                 997                425                     855
# 13                 732                152                    1127
# 14                 428                372                    1174
# 15                 789                294                    1737
# 16                 722                118                     535
# 17                 454                232                    1362
# 18                 878                419                    1951
# 19                 737                335                     899
# 20                 808                185                     824
# 21                 390                434                     869
# 22                 666                108                    1565
# 23                 458                310                    1661
#
#     Cases_Charge_Sheeted  Persons_Arrested
# 0                   1000              1028
# 1                    522               800
# 2                    224               712
# 3                    595              2037
# 4                    281              1297
# 5                    534               905
# 6                    858               739
# 7                    418               900
# 8                    663              1078
# 9                    998              2437
# 10                   262              1980
# 11                   630              1303
# 12                   292              1719
# 13                   978              2975
# 14                   309              2632
# 15                   869              1744
# 16                   951              1912
# 17                   512              2194
# 18                   580               780
# 19                   722              2565
# 20                   995               809
# 21                   488              1518
# 22                   901              1814
# 23                   553              2866

# %% [markdown]
# ##### 1. On the above code I have generated a dataframe using faker,numpy,pandas & random where fake informations has been generated with random numbers in the year 2000 to 2023.

# %%
# Add NaN values for the years 2000 to 2023 
nan_years = random.sample(range(2000, 2024), 5)  # Randomly choose 5 years
for year in nan_years:
    df.loc[df['Year'] == str(year), df.columns[2:]] = np.nan

# Add null values for the years 2000 to 2023 
null_years = random.sample(range(2000, 2024), 5)  # Randomly choose 5 years
for year in null_years:
    df.loc[df['Year'] == str(year), df.columns[2:]] = None

# Add duplicated values for the years 2000 to 2023 
dup_years = random.sample(range(2000, 2024), 5)  # Randomly choose 5 years
for year in dup_years:
    df = pd.concat([df, df[df['Year'] == str(year)]], ignore_index=True)    #To set the index sequentially in the resulting dataframe

# Display the DataFrame
print(df)
# Out:
#     Year  Total_Cybercrimes  Financial_Fraud  Identity_Theft  Cyberbullying  \
# 0   2000              31118              NaN             NaN            NaN
# 1   2001              12594           9082.0          1447.0         2468.0
# 2   2002              46936           4069.0          1539.0         1030.0
# 3   2003              42585           4973.0          6396.0         1542.0
# 4   2004              37195              NaN             NaN            NaN
# 5   2005              14767           6252.0          6177.0         1507.0
# 6   2006              35637              NaN             NaN            NaN
# 7   2007              29142           6073.0          4886.0         1885.0
# 8   2008              26564           7568.0          1103.0         2898.0
# 9   2009              27821              NaN             NaN            NaN
# 10  2010              46077           6736.0          2602.0         2422.0
# 11  2011              16826           8198.0          5786.0         2381.0
# 12  2012              44134              NaN             NaN            NaN
# 13  2013              25374           5638.0          7934.0          876.0
# 14  2014              32672           5342.0          4937.0         2602.0
# 15  2015              49596           2075.0          4605.0         1922.0
# 16  2016              14167              NaN             NaN            NaN
# 17  2017              34129              NaN             NaN            NaN
# 18  2018              47669              NaN             NaN            NaN
# 19  2019              42941              NaN             NaN            NaN
# 20  2020              22873           7885.0          3807.0         1848.0
# 21  2021              36982           7278.0          4968.0         2807.0
# 22  2022              20845           3796.0          4875.0         2356.0
# 23  2023              23012           4661.0          4440.0         2405.0
# 24  2009              27821              NaN             NaN            NaN
# 25  2020              22873           7885.0          3807.0         1848.0
# 26  2000              31118              NaN             NaN            NaN
# 27  2006              35637              NaN             NaN            NaN
# 28  2015              49596           2075.0          4605.0         1922.0
#
#     Hacking  Data_Breaches  Economic_Cybercrimes  Online_Scams  \
# 0       NaN            NaN                   NaN           NaN
# 1    4415.0         2705.0                3903.0        1143.0
# 2    3943.0         1014.0                7052.0         511.0
# 3     368.0         1299.0                9785.0         656.0
# 4       NaN            NaN                   NaN           NaN
# 5    3001.0         1817.0                9433.0        1208.0
# 6       NaN            NaN                   NaN           NaN
# 7    3657.0         3547.0                4744.0         807.0
# 8    4383.0          755.0                5655.0        1866.0
# 9       NaN            NaN                   NaN           NaN
# 10   4168.0          839.0                6443.0        1019.0
# 11   3061.0          756.0                5920.0        1515.0
# 12      NaN            NaN                   NaN           NaN
# 13   1100.0         2621.0                7886.0        1238.0
# 14   2660.0         3252.0                8570.0        1155.0
# 15   4903.0         1357.0                6781.0        1748.0
# 16      NaN            NaN                   NaN           NaN
# 17      NaN            NaN                   NaN           NaN
# 18      NaN            NaN                   NaN           NaN
# 19      NaN            NaN                   NaN           NaN
# 20   1778.0         1290.0                1920.0        1093.0
# 21    325.0         2718.0                1918.0         805.0
# 22   4839.0          645.0                6787.0        1102.0
# 23   2280.0         2474.0                5201.0         900.0
# 24      NaN            NaN                   NaN           NaN
# 25   1778.0         1290.0                1920.0        1093.0
# 26      NaN            NaN                   NaN           NaN
# 27      NaN            NaN                   NaN           NaN
# 28   4903.0         1357.0                6781.0        1748.0
#
#     Phishing_Attacks  Ransomware_Attacks  Malware_Infections  \
# 0                NaN                 NaN                 NaN
# 1              969.0               167.0              2143.0
# 2              492.0               255.0              1384.0
# 3              630.0               373.0              2684.0
# 4                NaN                 NaN                 NaN
# 5              288.0               494.0               979.0
# 6                NaN                 NaN                 NaN
# 7              894.0               400.0              2144.0
# 8              540.0               252.0              2717.0
# 9                NaN                 NaN                 NaN
# 10             456.0               404.0              2477.0
# 11             744.0               304.0              2358.0
# 12               NaN                 NaN                 NaN
# 13             485.0               483.0               900.0
# 14             929.0               181.0              1650.0
# 15             719.0               174.0              1433.0
# 16               NaN                 NaN                 NaN
# 17               NaN                 NaN                 NaN
# 18               NaN                 NaN                 NaN
# 19               NaN                 NaN                 NaN
# 20             895.0               191.0              2164.0
# 21             342.0               363.0              1249.0
# 22             762.0               324.0               851.0
# 23             849.0               364.0              2857.0
# 24               NaN                 NaN                 NaN
# 25             895.0               191.0              2164.0
# 26               NaN                 NaN                 NaN
# 27               NaN                 NaN                 NaN
# 28             719.0               174.0              1433.0
#
#     Social_Media_Fraud  Dark_Web_Activity  Cybersecurity_Breaches  \
# 0                  NaN                NaN                     NaN
# 1                236.0              142.0                   712.0
# 2                579.0              137.0                  1624.0
# 3                739.0              321.0                   548.0
# 4                  NaN                NaN                     NaN
# 5                524.0              207.0                  1063.0
# 6                  NaN                NaN                     NaN
# 7                274.0              222.0                  1377.0
# 8                747.0              107.0                   913.0
# 9                  NaN                NaN                     NaN
# 10               851.0              161.0                   827.0
# 11               745.0              150.0                  1393.0
# 12                 NaN                NaN                     NaN
# 13               732.0              152.0                  1127.0
# 14               428.0              372.0                  1174.0
# 15               789.0              294.0                  1737.0
# 16                 NaN                NaN                     NaN
# 17                 NaN                NaN                     NaN
# 18                 NaN                NaN                     NaN
# 19                 NaN                NaN                     NaN
# 20               808.0              185.0                   824.0
# 21               390.0              434.0                   869.0
# 22               666.0              108.0                  1565.0
# 23               458.0              310.0                  1661.0
# 24                 NaN                NaN                     NaN
# 25               808.0              185.0                   824.0
# 26                 NaN                NaN                     NaN
# 27                 NaN                NaN                     NaN
# 28               789.0              294.0                  1737.0
#
#     Cases_Charge_Sheeted  Persons_Arrested
# 0                    NaN               NaN
# 1                  522.0             800.0
# 2                  224.0             712.0
# 3                  595.0            2037.0
# 4                    NaN               NaN
# 5                  534.0             905.0
# 6                    NaN               NaN
# 7                  418.0             900.0
# 8                  663.0            1078.0
# 9                    NaN               NaN
# 10                 262.0            1980.0
# 11                 630.0            1303.0
# 12                   NaN               NaN
# 13                 978.0            2975.0
# 14                 309.0            2632.0
# 15                 869.0            1744.0
# 16                   NaN               NaN
# 17                   NaN               NaN
# 18                   NaN               NaN
# 19                   NaN               NaN
# 20                 995.0             809.0
# 21                 488.0            1518.0
# 22                 901.0            1814.0
# 23                 553.0            2866.0
# 24                   NaN               NaN
# 25                 995.0             809.0
# 26                   NaN               NaN
# 27                   NaN               NaN
# 28                 869.0            1744.0

# %% [markdown]
# ##### 2. On the next step I have added some nan values,null values & duplicated values on the dataframe excluding the 'Year' column where the range() function generates a range of years from 2000 to 2023 and random.sample() function randomly selects 5 unique years from 2000 to 2023.
# ##### 3. I have used loc[] to select rows based on the condition and selected columns for slicing inside the loop
# ##### 4. I have concatenated the dataframe itself with the rows effectively duplicates rows corresponding to the selected years and appends them to the dataframe

# %%
#Create data for the new column
new_column=['Tamil Nadu','Telangana','Rajasthan','Jharkhand','Assam','Punjab','Andhra Pradesh','Odisha','West Bengal','Maharashtra','Uttar Pradesh','Jharkhand','Assam','Andhra Pradesh','Telangana','Madhya Pradesh','Rajasthan','Kerala','Karnataka','Bihar','Andhra Pradesh','Telangana','Assam',' Madhya Pradesh','Tamil Nadu','Andhra Pradesh',' Rajasthan','Punjab','Odisha']
#Giving a new column name and storing it into a variable
column_name='States'
#Insert as the second column (index 1)
insert_index=1  
#Updating the dataframe
df.insert(insert_index,column_name,new_column)
print("Dataframe after adding new column:")
df
# Out:
# Dataframe after adding new column:
#     Year           States  Total_Cybercrimes  Financial_Fraud  Identity_Theft  \
# 0   2000       Tamil Nadu              31118              NaN             NaN
# 1   2001        Telangana              12594           9082.0          1447.0
# 2   2002        Rajasthan              46936           4069.0          1539.0
# 3   2003        Jharkhand              42585           4973.0          6396.0
# 4   2004            Assam              37195              NaN             NaN
# 5   2005           Punjab              14767           6252.0          6177.0
# 6   2006   Andhra Pradesh              35637              NaN             NaN
# 7   2007           Odisha              29142           6073.0          4886.0
# 8   2008      West Bengal              26564           7568.0          1103.0
# 9   2009      Maharashtra              27821              NaN             NaN
# 10  2010    Uttar Pradesh              46077           6736.0          2602.0
# 11  2011        Jharkhand              16826           8198.0          5786.0
# 12  2012            Assam              44134              NaN             NaN
# 13  2013   Andhra Pradesh              25374           5638.0          7934.0
# 14  2014        Telangana              32672           5342.0          4937.0
# 15  2015   Madhya Pradesh              49596           2075.0          4605.0
# 16  2016        Rajasthan              14167              NaN             NaN
# 17  2017           Kerala              34129              NaN             NaN
# 18  2018        Karnataka              47669              NaN             NaN
# 19  2019            Bihar              42941              NaN             NaN
# 20  2020   Andhra Pradesh              22873           7885.0          3807.0
# 21  2021        Telangana              36982           7278.0          4968.0
# 22  2022            Assam              20845           3796.0          4875.0
# 23  2023   Madhya Pradesh              23012           4661.0          4440.0
# 24  2009       Tamil Nadu              27821              NaN             NaN
# 25  2020   Andhra Pradesh              22873           7885.0          3807.0
# 26  2000        Rajasthan              31118              NaN             NaN
# 27  2006           Punjab              35637              NaN             NaN
# 28  2015           Odisha              49596           2075.0          4605.0
#
#     Cyberbullying  Hacking  Data_Breaches  Economic_Cybercrimes  Online_Scams  \
# 0             NaN      NaN            NaN                   NaN           NaN
# 1          2468.0   4415.0         2705.0                3903.0        1143.0
# 2          1030.0   3943.0         1014.0                7052.0         511.0
# 3          1542.0    368.0         1299.0                9785.0         656.0
# 4             NaN      NaN            NaN                   NaN           NaN
# 5          1507.0   3001.0         1817.0                9433.0        1208.0
# 6             NaN      NaN            NaN                   NaN           NaN
# 7          1885.0   3657.0         3547.0                4744.0         807.0
# 8          2898.0   4383.0          755.0                5655.0        1866.0
# 9             NaN      NaN            NaN                   NaN           NaN
# 10         2422.0   4168.0          839.0                6443.0        1019.0
# 11         2381.0   3061.0          756.0                5920.0        1515.0
# 12            NaN      NaN            NaN                   NaN           NaN
# 13          876.0   1100.0         2621.0                7886.0        1238.0
# 14         2602.0   2660.0         3252.0                8570.0        1155.0
# 15         1922.0   4903.0         1357.0                6781.0        1748.0
# 16            NaN      NaN            NaN                   NaN           NaN
# 17            NaN      NaN            NaN                   NaN           NaN
# 18            NaN      NaN            NaN                   NaN           NaN
# 19            NaN      NaN            NaN                   NaN           NaN
# 20         1848.0   1778.0         1290.0                1920.0        1093.0
# 21         2807.0    325.0         2718.0                1918.0         805.0
# 22         2356.0   4839.0          645.0                6787.0        1102.0
# 23         2405.0   2280.0         2474.0                5201.0         900.0
# 24            NaN      NaN            NaN                   NaN           NaN
# 25         1848.0   1778.0         1290.0                1920.0        1093.0
# 26            NaN      NaN            NaN                   NaN           NaN
# 27            NaN      NaN            NaN                   NaN           NaN
# 28         1922.0   4903.0         1357.0                6781.0        1748.0
#
#     Phishing_Attacks  Ransomware_Attacks  Malware_Infections  \
# 0                NaN                 NaN                 NaN
# 1              969.0               167.0              2143.0
# 2              492.0               255.0              1384.0
# 3              630.0               373.0              2684.0
# 4                NaN                 NaN                 NaN
# 5              288.0               494.0               979.0
# 6                NaN                 NaN                 NaN
# 7              894.0               400.0              2144.0
# 8              540.0               252.0              2717.0
# 9                NaN                 NaN                 NaN
# 10             456.0               404.0              2477.0
# 11             744.0               304.0              2358.0
# 12               NaN                 NaN                 NaN
# 13             485.0               483.0               900.0
# 14             929.0               181.0              1650.0
# 15             719.0               174.0              1433.0
# 16               NaN                 NaN                 NaN
# 17               NaN                 NaN                 NaN
# 18               NaN                 NaN                 NaN
# 19               NaN                 NaN                 NaN
# 20             895.0               191.0              2164.0
# 21             342.0               363.0              1249.0
# 22             762.0               324.0               851.0
# 23             849.0               364.0              2857.0
# 24               NaN                 NaN                 NaN
# 25             895.0               191.0              2164.0
# 26               NaN                 NaN                 NaN
# 27               NaN                 NaN                 NaN
# 28             719.0               174.0              1433.0
#
#     Social_Media_Fraud  Dark_Web_Activity  Cybersecurity_Breaches  \
# 0                  NaN                NaN                     NaN
# 1                236.0              142.0                   712.0
# 2                579.0              137.0                  1624.0
# 3                739.0              321.0                   548.0
# 4                  NaN                NaN                     NaN
# 5                524.0              207.0                  1063.0
# 6                  NaN                NaN                     NaN
# 7                274.0              222.0                  1377.0
# 8                747.0              107.0                   913.0
# 9                  NaN                NaN                     NaN
# 10               851.0              161.0                   827.0
# 11               745.0              150.0                  1393.0
# 12                 NaN                NaN                     NaN
# 13               732.0              152.0                  1127.0
# 14               428.0              372.0                  1174.0
# 15               789.0              294.0                  1737.0
# 16                 NaN                NaN                     NaN
# 17                 NaN                NaN                     NaN
# 18                 NaN                NaN                     NaN
# 19                 NaN                NaN                     NaN
# 20               808.0              185.0                   824.0
# 21               390.0              434.0                   869.0
# 22               666.0              108.0                  1565.0
# 23               458.0              310.0                  1661.0
# 24                 NaN                NaN                     NaN
# 25               808.0              185.0                   824.0
# 26                 NaN                NaN                     NaN
# 27                 NaN                NaN                     NaN
# 28               789.0              294.0                  1737.0
#
#     Cases_Charge_Sheeted  Persons_Arrested
# 0                    NaN               NaN
# 1                  522.0             800.0
# 2                  224.0             712.0
# 3                  595.0            2037.0
# 4                    NaN               NaN
# 5                  534.0             905.0
# 6                    NaN               NaN
# 7                  418.0             900.0
# 8                  663.0            1078.0
# 9                    NaN               NaN
# 10                 262.0            1980.0
# 11                 630.0            1303.0
# 12                   NaN               NaN
# 13                 978.0            2975.0
# 14                 309.0            2632.0
# 15                 869.0            1744.0
# 16                   NaN               NaN
# 17                   NaN               NaN
# 18                   NaN               NaN
# 19                   NaN               NaN
# 20                 995.0             809.0
# 21                 488.0            1518.0
# 22                 901.0            1814.0
# 23                 553.0            2866.0
# 24                   NaN               NaN
# 25                 995.0             809.0
# 26                   NaN               NaN
# 27                   NaN               NaN
# 28                 869.0            1744.0

# %%
#Converting the dataframe to a new csv file
df.to_csv("Faker cyber crime data.csv",index=False)    #index=False meaning the dataframe's index is not included in the new csv file 
print("File saved")
# Out:
# File saved

# %%
#Importing librararies
import pandas as plt
import numpy as np
import matplotlib.pyplot as plt

#Reading the csv file
file_path="Faker cyber crime data.csv"
df=pd.read_csv(file_path)
#Printing data
df
# Out:
#     Year           States  Total_Cybercrimes  Financial_Fraud  Identity_Theft  \
# 0   2000       Tamil Nadu              31118              NaN             NaN
# 1   2001        Telangana              12594           9082.0          1447.0
# 2   2002        Rajasthan              46936           4069.0          1539.0
# 3   2003        Jharkhand              42585           4973.0          6396.0
# 4   2004            Assam              37195              NaN             NaN
# 5   2005           Punjab              14767           6252.0          6177.0
# 6   2006   Andhra Pradesh              35637              NaN             NaN
# 7   2007           Odisha              29142           6073.0          4886.0
# 8   2008      West Bengal              26564           7568.0          1103.0
# 9   2009      Maharashtra              27821              NaN             NaN
# 10  2010    Uttar Pradesh              46077           6736.0          2602.0
# 11  2011        Jharkhand              16826           8198.0          5786.0
# 12  2012            Assam              44134              NaN             NaN
# 13  2013   Andhra Pradesh              25374           5638.0          7934.0
# 14  2014        Telangana              32672           5342.0          4937.0
# 15  2015   Madhya Pradesh              49596           2075.0          4605.0
# 16  2016        Rajasthan              14167              NaN             NaN
# 17  2017           Kerala              34129              NaN             NaN
# 18  2018        Karnataka              47669              NaN             NaN
# 19  2019            Bihar              42941              NaN             NaN
# 20  2020   Andhra Pradesh              22873           7885.0          3807.0
# 21  2021        Telangana              36982           7278.0          4968.0
# 22  2022            Assam              20845           3796.0          4875.0
# 23  2023   Madhya Pradesh              23012           4661.0          4440.0
# 24  2009       Tamil Nadu              27821              NaN             NaN
# 25  2020   Andhra Pradesh              22873           7885.0          3807.0
# 26  2000        Rajasthan              31118              NaN             NaN
# 27  2006           Punjab              35637              NaN             NaN
# 28  2015           Odisha              49596           2075.0          4605.0
#
#     Cyberbullying  Hacking  Data_Breaches  Economic_Cybercrimes  Online_Scams  \
# 0             NaN      NaN            NaN                   NaN           NaN
# 1          2468.0   4415.0         2705.0                3903.0        1143.0
# 2          1030.0   3943.0         1014.0                7052.0         511.0
# 3          1542.0    368.0         1299.0                9785.0         656.0
# 4             NaN      NaN            NaN                   NaN           NaN
# 5          1507.0   3001.0         1817.0                9433.0        1208.0
# 6             NaN      NaN            NaN                   NaN           NaN
# 7          1885.0   3657.0         3547.0                4744.0         807.0
# 8          2898.0   4383.0          755.0                5655.0        1866.0
# 9             NaN      NaN            NaN                   NaN           NaN
# 10         2422.0   4168.0          839.0                6443.0        1019.0
# 11         2381.0   3061.0          756.0                5920.0        1515.0
# 12            NaN      NaN            NaN                   NaN           NaN
# 13          876.0   1100.0         2621.0                7886.0        1238.0
# 14         2602.0   2660.0         3252.0                8570.0        1155.0
# 15         1922.0   4903.0         1357.0                6781.0        1748.0
# 16            NaN      NaN            NaN                   NaN           NaN
# 17            NaN      NaN            NaN                   NaN           NaN
# 18            NaN      NaN            NaN                   NaN           NaN
# 19            NaN      NaN            NaN                   NaN           NaN
# 20         1848.0   1778.0         1290.0                1920.0        1093.0
# 21         2807.0    325.0         2718.0                1918.0         805.0
# 22         2356.0   4839.0          645.0                6787.0        1102.0
# 23         2405.0   2280.0         2474.0                5201.0         900.0
# 24            NaN      NaN            NaN                   NaN           NaN
# 25         1848.0   1778.0         1290.0                1920.0        1093.0
# 26            NaN      NaN            NaN                   NaN           NaN
# 27            NaN      NaN            NaN                   NaN           NaN
# 28         1922.0   4903.0         1357.0                6781.0        1748.0
#
#     Phishing_Attacks  Ransomware_Attacks  Malware_Infections  \
# 0                NaN                 NaN                 NaN
# 1              969.0               167.0              2143.0
# 2              492.0               255.0              1384.0
# 3              630.0               373.0              2684.0
# 4                NaN                 NaN                 NaN
# 5              288.0               494.0               979.0
# 6                NaN                 NaN                 NaN
# 7              894.0               400.0              2144.0
# 8              540.0               252.0              2717.0
# 9                NaN                 NaN                 NaN
# 10             456.0               404.0              2477.0
# 11             744.0               304.0              2358.0
# 12               NaN                 NaN                 NaN
# 13             485.0               483.0               900.0
# 14             929.0               181.0              1650.0
# 15             719.0               174.0              1433.0
# 16               NaN                 NaN                 NaN
# 17               NaN                 NaN                 NaN
# 18               NaN                 NaN                 NaN
# 19               NaN                 NaN                 NaN
# 20             895.0               191.0              2164.0
# 21             342.0               363.0              1249.0
# 22             762.0               324.0               851.0
# 23             849.0               364.0              2857.0
# 24               NaN                 NaN                 NaN
# 25             895.0               191.0              2164.0
# 26               NaN                 NaN                 NaN
# 27               NaN                 NaN                 NaN
# 28             719.0               174.0              1433.0
#
#     Social_Media_Fraud  Dark_Web_Activity  Cybersecurity_Breaches  \
# 0                  NaN                NaN                     NaN
# 1                236.0              142.0                   712.0
# 2                579.0              137.0                  1624.0
# 3                739.0              321.0                   548.0
# 4                  NaN                NaN                     NaN
# 5                524.0              207.0                  1063.0
# 6                  NaN                NaN                     NaN
# 7                274.0              222.0                  1377.0
# 8                747.0              107.0                   913.0
# 9                  NaN                NaN                     NaN
# 10               851.0              161.0                   827.0
# 11               745.0              150.0                  1393.0
# 12                 NaN                NaN                     NaN
# 13               732.0              152.0                  1127.0
# 14               428.0              372.0                  1174.0
# 15               789.0              294.0                  1737.0
# 16                 NaN                NaN                     NaN
# 17                 NaN                NaN                     NaN
# 18                 NaN                NaN                     NaN
# 19                 NaN                NaN                     NaN
# 20               808.0              185.0                   824.0
# 21               390.0              434.0                   869.0
# 22               666.0              108.0                  1565.0
# 23               458.0              310.0                  1661.0
# 24                 NaN                NaN                     NaN
# 25               808.0              185.0                   824.0
# 26                 NaN                NaN                     NaN
# 27                 NaN                NaN                     NaN
# 28               789.0              294.0                  1737.0
#
#     Cases_Charge_Sheeted  Persons_Arrested
# 0                    NaN               NaN
# 1                  522.0             800.0
# 2                  224.0             712.0
# 3                  595.0            2037.0
# 4                    NaN               NaN
# 5                  534.0             905.0
# 6                    NaN               NaN
# 7                  418.0             900.0
# 8                  663.0            1078.0
# 9                    NaN               NaN
# 10                 262.0            1980.0
# 11                 630.0            1303.0
# 12                   NaN               NaN
# 13                 978.0            2975.0
# 14                 309.0            2632.0
# 15                 869.0            1744.0
# 16                   NaN               NaN
# 17                   NaN               NaN
# 18                   NaN               NaN
# 19                   NaN               NaN
# 20                 995.0             809.0
# 21                 488.0            1518.0
# 22                 901.0            1814.0
# 23                 553.0            2866.0
# 24                   NaN               NaN
# 25                 995.0             809.0
# 26                   NaN               NaN
# 27                   NaN               NaN
# 28                 869.0            1744.0

# %%
#Data Exploration
df.info()          #It provides datatypes,total columns,non-null counts,no. of index entries,memory usage
df.describe().T    #It provides various summary statistics for numerical columns in dataftame by transforming the display
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    29 non-null     int64
#  1   States                  29 non-null     object
#  2   Total_Cybercrimes       29 non-null     int64
#  3   Financial_Fraud         17 non-null     float64
#  4   Identity_Theft          17 non-null     float64
#  5   Cyberbullying           17 non-null     float64
#  6   Hacking                 17 non-null     float64
#  7   Data_Breaches           17 non-null     float64
#  8   Economic_Cybercrimes    17 non-null     float64
#  9   Online_Scams            17 non-null     float64
#  10  Phishing_Attacks        17 non-null     float64
#  11  Ransomware_Attacks      17 non-null     float64
#  12  Malware_Infections      17 non-null     float64
#  13  Social_Media_Fraud      17 non-null     float64
#  14  Dark_Web_Activity       17 non-null     float64
#  15  Cybersecurity_Breaches  17 non-null     float64
#  16  Cases_Charge_Sheeted    17 non-null     float64
#  17  Persons_Arrested        17 non-null     float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 4.2+ KB
#                         count          mean           std      min      25%  \
# Year                     29.0   2011.241379      7.074376   2000.0   2006.0
# Total_Cybercrimes        29.0  32024.172414  11116.234316  12594.0  23012.0
# Financial_Fraud          17.0   5858.000000   2070.708091   2075.0   4661.0
# Identity_Theft           17.0   4347.882353   1843.502539   1103.0   3807.0
# Cyberbullying            17.0   2042.294118    578.325575    876.0   1848.0
# Hacking                  17.0   3033.058824   1551.683258    325.0   1778.0
# Data_Breaches            17.0   1749.176471    939.672765    645.0   1014.0
# Economic_Cybercrimes     17.0   5923.470588   2449.624770   1918.0   4744.0
# Online_Scams             17.0   1153.352941    383.207995    511.0    900.0
# Phishing_Attacks         17.0    682.823529    215.001231    288.0    492.0
# Ransomware_Attacks       17.0    299.647059    111.135582    167.0    191.0
# Malware_Infections       17.0   1858.058824    666.433462    851.0   1384.0
# Social_Media_Fraud       17.0    621.352941    199.341397    236.0    458.0
# Dark_Web_Activity        17.0    222.411765     97.457721    107.0    150.0
# Cybersecurity_Breaches   17.0   1175.000000    392.272705    548.0    827.0
# Cases_Charge_Sheeted     17.0    635.588235    258.872328    224.0    488.0
# Persons_Arrested         17.0   1566.235294    749.250002    712.0    900.0
#
#                             50%      75%      max
# Year                     2011.0   2017.0   2023.0
# Total_Cybercrimes       31118.0  42585.0  49596.0
# Financial_Fraud          6073.0   7568.0   9082.0
# Identity_Theft           4605.0   4968.0   7934.0
# Cyberbullying            1922.0   2422.0   2898.0
# Hacking                  3061.0   4383.0   4903.0
# Data_Breaches            1357.0   2621.0   3547.0
# Economic_Cybercrimes     6443.0   7052.0   9785.0
# Online_Scams             1102.0   1238.0   1866.0
# Phishing_Attacks          719.0    894.0    969.0
# Ransomware_Attacks        304.0    373.0    494.0
# Malware_Infections       2143.0   2358.0   2857.0
# Social_Media_Fraud        732.0    789.0    851.0
# Dark_Web_Activity         185.0    294.0    434.0
# Cybersecurity_Breaches   1127.0   1565.0   1737.0
# Cases_Charge_Sheeted      595.0    869.0    995.0
# Persons_Arrested         1518.0   1980.0   2975.0

# %%
#Checking missing values
print("Checking number of missig values:")
df.isnull().sum()                     #isnull().sum() giving the sum of null values
# Out:
# Checking number of missig values:
# Year                       0
# States                     0
# Total_Cybercrimes          0
# Financial_Fraud           12
# Identity_Theft            12
# Cyberbullying             12
# Hacking                   12
# Data_Breaches             12
# Economic_Cybercrimes      12
# Online_Scams              12
# Phishing_Attacks          12
# Ransomware_Attacks        12
# Malware_Infections        12
# Social_Media_Fraud        12
# Dark_Web_Activity         12
# Cybersecurity_Breaches    12
# Cases_Charge_Sheeted      12
# Persons_Arrested          12
# dtype: int64

# %%
#Data Cleaning
print("Before Removing nan values:")   #dropna() used to remove Not a Number(NaN) values called as missing values
df.info()
df.dropna(inplace=True)                #inplace=True means modifications will happen in the original dataset
print("\nAfter Removing nan values:")
df.info()
# Out:
# Before Removing nan values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    29 non-null     int64
#  1   States                  29 non-null     object
#  2   Total_Cybercrimes       29 non-null     int64
#  3   Financial_Fraud         17 non-null     float64
#  4   Identity_Theft          17 non-null     float64
#  5   Cyberbullying           17 non-null     float64
#  6   Hacking                 17 non-null     float64
#  7   Data_Breaches           17 non-null     float64
#  8   Economic_Cybercrimes    17 non-null     float64
#  9   Online_Scams            17 non-null     float64
#  10  Phishing_Attacks        17 non-null     float64
#  11  Ransomware_Attacks      17 non-null     float64
#  12  Malware_Infections      17 non-null     float64
#  13  Social_Media_Fraud      17 non-null     float64
#  14  Dark_Web_Activity       17 non-null     float64
#  15  Cybersecurity_Breaches  17 non-null     float64
#  16  Cases_Charge_Sheeted    17 non-null     float64
#  17  Persons_Arrested        17 non-null     float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 4.2+ KB
#
# After Removing nan values:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 1 to 28
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Year                    17 non-null     int64
#  1   States                  17 non-null     object
#  2   Total_Cybercrimes       17 non-null     int64
#  3   Financial_Fraud         17 non-null     float64
#  4   Identity_Theft          17 non-null     float64
#  5   Cyberbullying           17 non-null     float64
#  6   Hacking                 17 non-null     float64
#  7   Data_Breaches           17 non-null     float64
#  8   Economic_Cybercrimes    17 non-null     float64
#  9   Online_Scams            17 non-null     float64
#  10  Phishing_Attacks        17 non-null     float64
#  11  Ransomware_Attacks      17 non-null     float64
#  12  Malware_Infections      17 non-null     float64
#  13  Social_Media_Fraud      17 non-null     float64
#  14  Dark_Web_Activity       17 non-null     float64
#  15  Cybersecurity_Breaches  17 non-null     float64
#  16  Cases_Charge_Sheeted    17 non-null     float64
#  17  Persons_Arrested        17 non-null     float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 2.5+ KB

# %%
#Finding Duplicated values to the rows if any
duplicate_rows=df.duplicated()                  #The duplicated() function is used to identify and mark duplicated rows in a DataFrame
print(f"Duplicates found: \n{duplicate_rows}")
print("Number of duplicate rows:",duplicate_rows.sum())  #Display the sum of duplicated rows in a dataframe
# Out:
# Duplicates found:
# 1     False
# 2     False
# 3     False
# 5     False
# 7     False
# 8     False
# 10    False
# 11    False
# 13    False
# 14    False
# 15    False
# 20    False
# 21    False
# 22    False
# 23    False
# 25     True
# 28    False
# dtype: bool
# Number of duplicate rows: 1

# %%
df.drop_duplicates(inplace=True)    #The drop_duplicates() function in is used to remove duplicate rows from a DataFrame
duplicate_rows=df.duplicated()
print("After Removing number of duplicate rows:",duplicate_rows.sum())
print(df[duplicate_rows])
# Out:
# After Removing number of duplicate rows: 0
# Empty DataFrame
# Columns: [Year, States, Total_Cybercrimes, Financial_Fraud, Identity_Theft, Cyberbullying, Hacking, Data_Breaches, Economic_Cybercrimes, Online_Scams, Phishing_Attacks, Ransomware_Attacks, Malware_Infections, Social_Media_Fraud, Dark_Web_Activity, Cybersecurity_Breaches, Cases_Charge_Sheeted, Persons_Arrested]
# Index: []

# %%
#Saving the cleaned file into a new csv file
df.to_csv("Cleaned cyber crime rate analysis file.csv",index=False)  #index=False meaning the dataframe's index is not included in the new csv file
print("File saved")
# Out:
# File saved

# %%
#Importing librararies
import pandas as plt
import numpy as np
import matplotlib.pyplot as plt

#Reading the csv file
file_path="Cleaned cyber crime rate analysis file.csv"
df=pd.read_csv(file_path)

#Printing data
df
# Out:
#     Year           States  Total_Cybercrimes  Financial_Fraud  Identity_Theft  \
# 0   2001        Telangana              12594           9082.0          1447.0
# 1   2002        Rajasthan              46936           4069.0          1539.0
# 2   2003        Jharkhand              42585           4973.0          6396.0
# 3   2005           Punjab              14767           6252.0          6177.0
# 4   2007           Odisha              29142           6073.0          4886.0
# 5   2008      West Bengal              26564           7568.0          1103.0
# 6   2010    Uttar Pradesh              46077           6736.0          2602.0
# 7   2011        Jharkhand              16826           8198.0          5786.0
# 8   2013   Andhra Pradesh              25374           5638.0          7934.0
# 9   2014        Telangana              32672           5342.0          4937.0
# 10  2015   Madhya Pradesh              49596           2075.0          4605.0
# 11  2020   Andhra Pradesh              22873           7885.0          3807.0
# 12  2021        Telangana              36982           7278.0          4968.0
# 13  2022            Assam              20845           3796.0          4875.0
# 14  2023   Madhya Pradesh              23012           4661.0          4440.0
# 15  2015           Odisha              49596           2075.0          4605.0
#
#     Cyberbullying  Hacking  Data_Breaches  Economic_Cybercrimes  Online_Scams  \
# 0          2468.0   4415.0         2705.0                3903.0        1143.0
# 1          1030.0   3943.0         1014.0                7052.0         511.0
# 2          1542.0    368.0         1299.0                9785.0         656.0
# 3          1507.0   3001.0         1817.0                9433.0        1208.0
# 4          1885.0   3657.0         3547.0                4744.0         807.0
# 5          2898.0   4383.0          755.0                5655.0        1866.0
# 6          2422.0   4168.0          839.0                6443.0        1019.0
# 7          2381.0   3061.0          756.0                5920.0        1515.0
# 8           876.0   1100.0         2621.0                7886.0        1238.0
# 9          2602.0   2660.0         3252.0                8570.0        1155.0
# 10         1922.0   4903.0         1357.0                6781.0        1748.0
# 11         1848.0   1778.0         1290.0                1920.0        1093.0
# 12         2807.0    325.0         2718.0                1918.0         805.0
# 13         2356.0   4839.0          645.0                6787.0        1102.0
# 14         2405.0   2280.0         2474.0                5201.0         900.0
# 15         1922.0   4903.0         1357.0                6781.0        1748.0
#
#     Phishing_Attacks  Ransomware_Attacks  Malware_Infections  \
# 0              969.0               167.0              2143.0
# 1              492.0               255.0              1384.0
# 2              630.0               373.0              2684.0
# 3              288.0               494.0               979.0
# 4              894.0               400.0              2144.0
# 5              540.0               252.0              2717.0
# 6              456.0               404.0              2477.0
# 7              744.0               304.0              2358.0
# 8              485.0               483.0               900.0
# 9              929.0               181.0              1650.0
# 10             719.0               174.0              1433.0
# 11             895.0               191.0              2164.0
# 12             342.0               363.0              1249.0
# 13             762.0               324.0               851.0
# 14             849.0               364.0              2857.0
# 15             719.0               174.0              1433.0
#
#     Social_Media_Fraud  Dark_Web_Activity  Cybersecurity_Breaches  \
# 0                236.0              142.0                   712.0
# 1                579.0              137.0                  1624.0
# 2                739.0              321.0                   548.0
# 3                524.0              207.0                  1063.0
# 4                274.0              222.0                  1377.0
# 5                747.0              107.0                   913.0
# 6                851.0              161.0                   827.0
# 7                745.0              150.0                  1393.0
# 8                732.0              152.0                  1127.0
# 9                428.0              372.0                  1174.0
# 10               789.0              294.0                  1737.0
# 11               808.0              185.0                   824.0
# 12               390.0              434.0                   869.0
# 13               666.0              108.0                  1565.0
# 14               458.0              310.0                  1661.0
# 15               789.0              294.0                  1737.0
#
#     Cases_Charge_Sheeted  Persons_Arrested
# 0                  522.0             800.0
# 1                  224.0             712.0
# 2                  595.0            2037.0
# 3                  534.0             905.0
# 4                  418.0             900.0
# 5                  663.0            1078.0
# 6                  262.0            1980.0
# 7                  630.0            1303.0
# 8                  978.0            2975.0
# 9                  309.0            2632.0
# 10                 869.0            1744.0
# 11                 995.0             809.0
# 12                 488.0            1518.0
# 13                 901.0            1814.0
# 14                 553.0            2866.0
# 15                 869.0            1744.0

# %%
#checking rows and columns in the dataframe
print("After removing nan values and duplicates number of rows and columns are:")
print(df.shape)
# Out:
# After removing nan values and duplicates number of rows and columns are:
# (16, 18)

# %%
#To display all unique values the unique() function is used with the desired column name
print(df['States'].unique())
# Out:
# ['Telangana' 'Rajasthan' 'Jharkhand' 'Punjab' 'Odisha' 'West Bengal'
#  'Uttar Pradesh' 'Andhra Pradesh' 'Madhya Pradesh' 'Assam'
#  ' Madhya Pradesh']

# %%
#To display the sum of count of all unique values nunique() function is used on the desired column name
print("Total of unique values:")
df['States'].nunique()
# Out:
# Total of unique values:
# 11

# %%
# Display the first ten rows of the DataFrame
df.head(10)
# Out:
#    Year          States  Total_Cybercrimes  Financial_Fraud  Identity_Theft  \
# 0  2001       Telangana              12594           9082.0          1447.0
# 1  2002       Rajasthan              46936           4069.0          1539.0
# 2  2003       Jharkhand              42585           4973.0          6396.0
# 3  2005          Punjab              14767           6252.0          6177.0
# 4  2007          Odisha              29142           6073.0          4886.0
# 5  2008     West Bengal              26564           7568.0          1103.0
# 6  2010   Uttar Pradesh              46077           6736.0          2602.0
# 7  2011       Jharkhand              16826           8198.0          5786.0
# 8  2013  Andhra Pradesh              25374           5638.0          7934.0
# 9  2014       Telangana              32672           5342.0          4937.0
#
#    Cyberbullying  Hacking  Data_Breaches  Economic_Cybercrimes  Online_Scams  \
# 0         2468.0   4415.0         2705.0                3903.0        1143.0
# 1         1030.0   3943.0         1014.0                7052.0         511.0
# 2         1542.0    368.0         1299.0                9785.0         656.0
# 3         1507.0   3001.0         1817.0                9433.0        1208.0
# 4         1885.0   3657.0         3547.0                4744.0         807.0
# 5         2898.0   4383.0          755.0                5655.0        1866.0
# 6         2422.0   4168.0          839.0                6443.0        1019.0
# 7         2381.0   3061.0          756.0                5920.0        1515.0
# 8          876.0   1100.0         2621.0                7886.0        1238.0
# 9         2602.0   2660.0         3252.0                8570.0        1155.0
#
#    Phishing_Attacks  Ransomware_Attacks  Malware_Infections  \
# 0             969.0               167.0              2143.0
# 1             492.0               255.0              1384.0
# 2             630.0               373.0              2684.0
# 3             288.0               494.0               979.0
# 4             894.0               400.0              2144.0
# 5             540.0               252.0              2717.0
# 6             456.0               404.0              2477.0
# 7             744.0               304.0              2358.0
# 8             485.0               483.0               900.0
# 9             929.0               181.0              1650.0
#
#    Social_Media_Fraud  Dark_Web_Activity  Cybersecurity_Breaches  \
# 0               236.0              142.0                   712.0
# 1               579.0              137.0                  1624.0
# 2               739.0              321.0                   548.0
# 3               524.0              207.0                  1063.0
# 4               274.0              222.0                  1377.0
# 5               747.0              107.0                   913.0
# 6               851.0              161.0                   827.0
# 7               745.0              150.0                  1393.0
# 8               732.0              152.0                  1127.0
# 9               428.0              372.0                  1174.0
#
#    Cases_Charge_Sheeted  Persons_Arrested
# 0                 522.0             800.0
# 1                 224.0             712.0
# 2                 595.0            2037.0
# 3                 534.0             905.0
# 4                 418.0             900.0
# 5                 663.0            1078.0
# 6                 262.0            1980.0
# 7                 630.0            1303.0
# 8                 978.0            2975.0
# 9                 309.0            2632.0

# %%
#Displaying columnns having largest values out of ten values
print("Highest number of Cases Charge Sheeted\n")
df.nlargest(7,'Total_Cybercrimes').head(10)
# Out:
# Highest number of Cases Charge Sheeted
#     Year          States  Total_Cybercrimes  Financial_Fraud  Identity_Theft  \
# 10  2015  Madhya Pradesh              49596           2075.0          4605.0
# 15  2015          Odisha              49596           2075.0          4605.0
# 1   2002       Rajasthan              46936           4069.0          1539.0
# 6   2010   Uttar Pradesh              46077           6736.0          2602.0
# 2   2003       Jharkhand              42585           4973.0          6396.0
# 12  2021       Telangana              36982           7278.0          4968.0
# 9   2014       Telangana              32672           5342.0          4937.0
#
#     Cyberbullying  Hacking  Data_Breaches  Economic_Cybercrimes  Online_Scams  \
# 10         1922.0   4903.0         1357.0                6781.0        1748.0
# 15         1922.0   4903.0         1357.0                6781.0        1748.0
# 1          1030.0   3943.0         1014.0                7052.0         511.0
# 6          2422.0   4168.0          839.0                6443.0        1019.0
# 2          1542.0    368.0         1299.0                9785.0         656.0
# 12         2807.0    325.0         2718.0                1918.0         805.0
# 9          2602.0   2660.0         3252.0                8570.0        1155.0
#
#     Phishing_Attacks  Ransomware_Attacks  Malware_Infections  \
# 10             719.0               174.0              1433.0
# 15             719.0               174.0              1433.0
# 1              492.0               255.0              1384.0
# 6              456.0               404.0              2477.0
# 2              630.0               373.0              2684.0
# 12             342.0               363.0              1249.0
# 9              929.0               181.0              1650.0
#
#     Social_Media_Fraud  Dark_Web_Activity  Cybersecurity_Breaches  \
# 10               789.0              294.0                  1737.0
# 15               789.0              294.0                  1737.0
# 1                579.0              137.0                  1624.0
# 6                851.0              161.0                   827.0
# 2                739.0              321.0                   548.0
# 12               390.0              434.0                   869.0
# 9                428.0              372.0                  1174.0
#
#     Cases_Charge_Sheeted  Persons_Arrested
# 10                 869.0            1744.0
# 15                 869.0            1744.0
# 1                  224.0             712.0
# 6                  262.0            1980.0
# 2                  595.0            2037.0
# 12                 488.0            1518.0
# 9                  309.0            2632.0

# %%
#Displaying columnns having smallest values out of ten values
print("Lowest number of Cases Charge Sheeted\n")
df.nsmallest(7,'Total_Cybercrimes').head(10)
# Out:
# Lowest number of Cases Charge Sheeted
#     Year           States  Total_Cybercrimes  Financial_Fraud  Identity_Theft  \
# 0   2001        Telangana              12594           9082.0          1447.0
# 3   2005           Punjab              14767           6252.0          6177.0
# 7   2011        Jharkhand              16826           8198.0          5786.0
# 13  2022            Assam              20845           3796.0          4875.0
# 11  2020   Andhra Pradesh              22873           7885.0          3807.0
# 14  2023   Madhya Pradesh              23012           4661.0          4440.0
# 8   2013   Andhra Pradesh              25374           5638.0          7934.0
#
#     Cyberbullying  Hacking  Data_Breaches  Economic_Cybercrimes  Online_Scams  \
# 0          2468.0   4415.0         2705.0                3903.0        1143.0
# 3          1507.0   3001.0         1817.0                9433.0        1208.0
# 7          2381.0   3061.0          756.0                5920.0        1515.0
# 13         2356.0   4839.0          645.0                6787.0        1102.0
# 11         1848.0   1778.0         1290.0                1920.0        1093.0
# 14         2405.0   2280.0         2474.0                5201.0         900.0
# 8           876.0   1100.0         2621.0                7886.0        1238.0
#
#     Phishing_Attacks  Ransomware_Attacks  Malware_Infections  \
# 0              969.0               167.0              2143.0
# 3              288.0               494.0               979.0
# 7              744.0               304.0              2358.0
# 13             762.0               324.0               851.0
# 11             895.0               191.0              2164.0
# 14             849.0               364.0              2857.0
# 8              485.0               483.0               900.0
#
#     Social_Media_Fraud  Dark_Web_Activity  Cybersecurity_Breaches  \
# 0                236.0              142.0                   712.0
# 3                524.0              207.0                  1063.0
# 7                745.0              150.0                  1393.0
# 13               666.0              108.0                  1565.0
# 11               808.0              185.0                   824.0
# 14               458.0              310.0                  1661.0
# 8                732.0              152.0                  1127.0
#
#     Cases_Charge_Sheeted  Persons_Arrested
# 0                  522.0             800.0
# 3                  534.0             905.0
# 7                  630.0            1303.0
# 13                 901.0            1814.0
# 11                 995.0             809.0
# 14                 553.0            2866.0
# 8                  978.0            2975.0

# %%
#By using groupby() function to find out the maximum values of mentioned columns inside the dataframe by 'Year' 
df[['States','Year','Financial_Fraud','Economic_Cybercrimes','Cybersecurity_Breaches']].groupby(['Year']).max()
# Out:
#                States  Financial_Fraud  Economic_Cybercrimes  \
# Year
# 2001        Telangana           9082.0                3903.0
# 2002        Rajasthan           4069.0                7052.0
# 2003        Jharkhand           4973.0                9785.0
# 2005           Punjab           6252.0                9433.0
# 2007           Odisha           6073.0                4744.0
# 2008      West Bengal           7568.0                5655.0
# 2010    Uttar Pradesh           6736.0                6443.0
# 2011        Jharkhand           8198.0                5920.0
# 2013   Andhra Pradesh           5638.0                7886.0
# 2014        Telangana           5342.0                8570.0
# 2015           Odisha           2075.0                6781.0
# 2020   Andhra Pradesh           7885.0                1920.0
# 2021        Telangana           7278.0                1918.0
# 2022            Assam           3796.0                6787.0
# 2023   Madhya Pradesh           4661.0                5201.0
#
#       Cybersecurity_Breaches
# Year
# 2001                   712.0
# 2002                  1624.0
# 2003                   548.0
# 2005                  1063.0
# 2007                  1377.0
# 2008                   913.0
# 2010                   827.0
# 2011                  1393.0
# 2013                  1127.0
# 2014                  1174.0
# 2015                  1737.0
# 2020                   824.0
# 2021                   869.0
# 2022                  1565.0
# 2023                  1661.0

# %% [markdown]
# ### Trend Analysis

# %%
# To perform a trend analysis of various cybercrime categories over multiple years, excluding the total cybercrimes

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming 'df' as my DataFrame containing the data

# Select only the desired columns for analysis
columns_for_analysis = df[['Year','Financial_Fraud', 'Identity_Theft', 'Cyberbullying','Data_Breaches',
                           'Economic_Cybercrimes', 'Online_Scams', 'Phishing_Attacks', 
                           'Malware_Infections', 'Social_Media_Fraud', 'Dark_Web_Activity', 'Cybersecurity_Breaches']]

# Group by year and calculate mean for each column
yearly_mean = columns_for_analysis.groupby('Year').mean()

# Plot bar chart for each column
plt.figure(figsize=(12, 8))
for column in yearly_mean.columns:
    plt.bar(yearly_mean.index, yearly_mean[column], label=column)
plt.xlabel('Year')
plt.ylabel('Mean Value')
plt.title('Trend Analysis of Cybercrime Data')
plt.legend()
plt.show()

# %% [markdown]
# ##### 5. After importing the necessary libraries like pandas,numpy & matplotlib I have selected the desired columns from the datafrme and stored into a variable.
# ##### 6. Then I have grouped the columns by year and calculated the mean.
# ##### 7. This code block generates a bar chart for each cybercrime category over the years. It iterates through each column in the yearly_mean DataFrame and plots a bar chart for each, with the year on the x-axis and the mean value on the y-axis.

# %% [markdown]
# ### State-wise Analysis

# %%
# Calculate total cybercrimes for each state

statewise_total = df.groupby('States')['Total_Cybercrimes'].sum().reset_index()

# Sort states by total cybercrimes in descending order
statewise_total = statewise_total.sort_values(by='Total_Cybercrimes', ascending=False)

# Plot bar chart for total cybercrimes by state
plt.figure(figsize=(10, 6))
plt.plot(statewise_total['States'], statewise_total['Total_Cybercrimes'],marker='o')
plt.xlabel('State')
plt.ylabel('Total Cybercrimes')
plt.title('Total Cybercrimes by State')
plt.xticks(rotation=90)      # Rotate x-axis labels for better readability
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 8. I have grouped the dataframe by 'States' column and calculated the sum of 'Total_Cybercrimes'column.
# ##### 9. Then I have sorted the dataframe by 'Total_Cybercrimes' column in descending order.
# ##### 10. This code block generates a line plot where 'States' is plotted on the x-axis, 'Total Cybercrimes' on the y-axis.

# %% [markdown]
# ### Correlation Matrix

# %%
#Different cybercrime categories correlate with each other

# Select only the desired columns for correlation analysis
columns_for_correlation = df[['Financial_Fraud', 'Identity_Theft', 'Cyberbullying', 'Data_Breaches',
                              'Economic_Cybercrimes', 'Online_Scams', 'Phishing_Attacks',
                              'Malware_Infections', 'Social_Media_Fraud', 'Dark_Web_Activity',
                              'Cybersecurity_Breaches']]

# Calculate correlation matrix for selected columns
correlation_matrix = columns_for_correlation.corr()

# Plot pie chart for each column's correlation with the first column
plt.figure(figsize=(12, 8))
first_column_correlation = correlation_matrix.iloc[:, 0]  # Select correlations with the first column
labels = first_column_correlation.index
plt.pie(np.abs(first_column_correlation), labels=labels, autopct='%1.1f%%', startangle=140)       #The absolute value of a number is its distance from 0 on the number line, without considering its direction (positive or negative). 
                                                                                                  #This function can handle both real and complex numbers.
plt.title('Correlation of Selected Columns with the First Column')
plt.show()

# %% [markdown]
# ##### 11. I have selected columns from the dataframe which computes the correlation matrix for the selected columns.
# ##### 12. This code block creates a pie chart to visualize the correlations of each column with the first column labels contains the column names for labeling each slice and autopct='%1.1f%%' formats the percentage displayed on each slice of the pie chart.

# %% [markdown]
# ### Arrests and Charge Sheet Analysis

# %%
# Plot scatter plots for arrests and charge sheets vs. total cybercrimes

plt.figure(figsize=(10, 6))
plt.scatter(df['Total_Cybercrimes'], df['Cases_Charge_Sheeted'], label='Cases Charge Sheeted')
plt.scatter(df['Total_Cybercrimes'], df['Persons_Arrested'], label='Persons Arrested')
plt.xlabel('Total Cybercrimes')
plt.ylabel('Number of Cases/Persons')
plt.title('Arrests and Charge Sheets vs. Total Cybercrimes')
plt.legend()
plt.grid(True)   # Add grid lines for better readability
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 13. This code block generates two scatter plot where the first plot represents the relationship between 'Total_Cybercrimes' and 'Cases_Charge_Sheeted' and the second plot represents the relationship between 'Total_Cybercrimes' and 'Persons_Arrested' including labels.
# ##### 14. Then I have adjusted he layout using grid() and tight_layout() methods for displaying the plot.

# %% [markdown]
# ### Time-Series Analysis

# %%
#Time-Series Analysis

# Convert the index to a DatetimeIndex
df.index = pd.to_datetime(df.index)

# Plot box plots for each column
plt.figure(figsize=(12, 6))
df.boxplot()
plt.xlabel('Variable')
plt.ylabel('Value')
plt.title('Box Plot of Time Series Data')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)  # Add grid lines for better readability
plt.show()

# %% [markdown]
# ##### 15. After converting the index of dataframe inti datatimeindex I have plotted a boxplot mentioning the figure size where labels are set for the  x-axis (Variable) and y-axis (Value) with a title.
# ##### 16.  Then I have adjusted he layout using grid() method for displaying the plot.
